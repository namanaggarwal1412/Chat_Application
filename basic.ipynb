# %%
print("hello world")
# variables
a=("Naman")
print(type(a))
#string
str="python is easy"
#indexing
print(str[2])
print(str[-1])
#slicing
print(str[2:5])
print(str[-4:-1])
print(str[::-1])
#string methods
#dictionary
student = {'name':'arya college','branch':'AI&DS'}
print(student)
print(True+True+False)
#add item in dictionary 
student['Age']=20
print(student['Age'])
a,b,c,d=(1,2,3,5)
a=1,2,3,4,5
print(type(a))
# data build
name = ('Naman')
print(type(name))
 
student['roll number']="22EAIAD069"
print(student['roll number'])

#Airthmetic operation
a=4
b=6
sum = (a+b)
print(sum)
mul=(a*b)
print(sum)
div=(a/b)
print(div)
#comparison
a=4
b=6
print(a==b)
print(a!=b)
print(a>b)
print(a>=b)
print(a<=b)
#Assignment Operators

#Assignment Operators

# Assignment Operations
a = 20
b = 10

# Basic Assignment
a = b
print("a =", a)  # Output: a = 10

# Add and Assign
a += b
print("a += b:", a)  # Output: a += b: 20 (10 + 10)

# Subtract and Assign
a -= b
print("a -= b:", a)  # Output: a -= b: 10 (20 - 10)

# Multiply and Assign
a *= b
print("a *= b:", a)  # Output: a *= b: 100 (10 * 10)

# Divide and Assign
a /= b
print("a /= b:", a)  # Output: a /= b: 10.0 (100 / 10)

# Modulus and Assign
a %= b
print("a %= b:", a)  # Output: a %= b: 0.0 (10.0 % 10)

# Exponent and Assign
a **= b
print("a **= b:", a)  # Output: a **= b: 0.0 (0.0 ** 10)

# Floor Division and Assign
a //= b
print("a //= b:", a)  # Output: a //= b: 0.0 (0.0 // 10)


#Bitwise operators
# Defining two numbers
a = 10  # Binary: 1010
b = 4   # Binary: 0100

# Bitwise AND
and_result = a & b  # 1010 & 0100 = 0000 (0)

# Bitwise OR
or_result = a | b   # 1010 | 0100 = 1110 (14)

# Bitwise XOR
xor_result = a ^ b  # 1010 ^ 0100 = 1110 (14)

# Bitwise NOT
not_a = ~a          # ~1010 = -(1010 + 1) = -11

# Left shift (shifting bits to the left by 2 places)
left_shift = a << 2  # 1010 << 2 = 101000 (40)

# Right shift (shifting bits to the right by 2 places)
right_shift = a >> 2  # 1010 >> 2 = 0010 (2)

# Printing results
print("a =", a, "b =", b)
print("Bitwise AND (a & b):", and_result)
print("Bitwise OR (a | b):", or_result)
print("Bitwise XOR (a ^ b):", xor_result)
print("Bitwise NOT (~a):", not_a)
print("Left Shift (a << 2):", left_shift)
print("Right Shift (a >> 2):", right_shift)



# Identity Operations
a = [1, 2, 3]
b = a   
c = [1, 2, 3]

# is operator
print(a is b)    

# is not operator
print(a is not c)

#Conditional statement
# Taking user input
num = int(input("Enter a number: "))

# Conditional statements
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# Another example with nested conditions
age = int(input("Enter your age: "))

if age >= 18:
    print("You are an adult.")
    if age >= 60:
        print("You are a senior citizen.")
    else:
        print("You are not a senior citizen yet.")
else:
    print("You are a minor.")
  
# Taking user input
num = int(input("Enter a number: "))

# Checking even or odd using conditional statement
if num % 2 == 0:
    print(f"{num} is an Even number.")
else:
    print(f"{num} is an Odd number.")
 # lemda function 
class Arya:
    a=10
    a1= Arya()
    print(a1,a)
# Out:
# hello world
# <class 'str'>
# t
# y
# tho
# eas
# ysae si nohtyp
# {'name': 'arya college', 'branch': 'AI&DS'}
# 2
# 20
# <class 'tuple'>
# <class 'str'>
# 22EAIAD069
# 10
# 10
# 0.6666666666666666
# False
# True
# False
# False
# True
# a = 10
# a += b: 20
# a -= b: 10
# a *= b: 100
# a /= b: 10.0
# a %= b: 0.0
# a **= b: 0.0
# a //= b: 0.0
# a = 10 b = 4
# Bitwise AND (a & b): 0
# Bitwise OR (a | b): 14
# Bitwise XOR (a ^ b): 14
# Bitwise NOT (~a): -11
# Left Shift (a << 2): 40
# Right Shift (a >> 2): 2
# True
# True

# %%
class Arya:
    def _init_(self):

# %%
a=[2,3,4,5,6,7]
for n in a:
    print(n)
student={'name':'naman','branch':'AI'}
for x in student.items():
    print(x)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# ('name', 'naman')
# ('branch', 'AI')

# %%
count=1
while count<=6:
       print(count)
       count +=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
class Arya:
    def __init__(self):
        self.a=10
a1= Arya()
print(a1.a)
# Out:
# 10

# %%
class Aryaold:
    def __init__(self, address, director_name):
        self.address = address
        self.director_name = director_name

    def display_info(self):
         print("Address:", self.address)
        print("Director Name:", self.director_name)

# Creating an object and printing details
aryaold_obj = Aryaold("kukas", "Arvind")
aryaold_obj.display_info()
# Out:
#   Cell In[10], line 2
#     def __init__(self, address, director_name):
#     ^
# IndentationError: expected an indented block after class definition on line 1
